# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly as py 
import plotly.tools as tls 
import cufflinks as cf 
# %matplotlib inline

# %%
df_4=pd.read_csv("C:\\Users\\lenovo\\Downloads\\archive (3)\\PointsTable.csv")

# %%
df_4.shape
# Out:
# (103, 10)

# %%
df_4.describe()
# Out:
#        Unnamed: 0  Total_Points_HomeTeam  Total_Points_AwayTeam  \
# count  103.000000             103.000000             103.000000
# mean    51.000000              32.699029              33.184466
# std     29.877528               7.061127               7.917154
# min      0.000000              19.000000              20.000000
# 25%     25.500000              28.000000              27.000000
# 50%     51.000000              32.000000              33.000000
# 75%     76.500000              38.500000              38.500000
# max    102.000000              50.000000              60.000000
#
#        FirstHalf_Points_HomeTeam  FirstHalf_Points_AwayTeam  \
# count                 103.000000                 103.000000
# mean                   14.844660                  14.844660
# std                     4.304027                   4.096285
# min                     8.000000                   7.000000
# 25%                    11.000000                  12.000000
# ...

# %%
df_4.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'HomeTeam', 'AwayTeam', 'Total_Points_HomeTeam',
#        'Total_Points_AwayTeam', 'FirstHalf_Points_HomeTeam',
#        'FirstHalf_Points_AwayTeam', 'SecondHalf_Points_HomeTeam',
#        'SecondHalf_Points_AwayTeam'],
#       dtype='object')

# %%
df_4.isnull().sum()
# Out:
# Unnamed: 0                    0
# Date                          0
# HomeTeam                      0
# AwayTeam                      0
# Total_Points_HomeTeam         0
# Total_Points_AwayTeam         0
# FirstHalf_Points_HomeTeam     0
# FirstHalf_Points_AwayTeam     0
# SecondHalf_Points_HomeTeam    0
# SecondHalf_Points_AwayTeam    0
# dtype: int64

# %%
x=df_4['HomeTeam']
y=df_4['AwayTeam']
plt.scatter(x,y)
plt.xlabel('HomeTeam',fontsize=10)
plt.ylabel('AwayTeam',fontsize=10)
# Out:
# Text(0, 0.5, 'AwayTeam')

# %%
plt.figure(figsize=(10,8))
sns.countplot(data=df_4,x='Total_Points_AwayTeam',hue='Total_Points_HomeTeam')
# Out:
# <AxesSubplot:xlabel='Total_Points_AwayTeam', ylabel='count'>

# %%
sns.boxplot('FirstHalf_Points_HomeTeam',data=df_4)
plt.show()
# Out:
# C:\Users\lenovo\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %%
sns.barplot('FirstHalf_Points_AwayTeam',data=df_4)
plt.show()
# Out:
# C:\Users\lenovo\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %%
sns.countplot('SecondHalf_Points_HomeTeam',data=df_4)
plt.show()
# Out:
# C:\Users\lenovo\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %%
sns.countplot('SecondHalf_Points_AwayTeam',data=df_4)
plt.show()
# Out:
# C:\Users\lenovo\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %%
df_4['SecondHalf_Points_HomeTeam'].plot(kind='bar',figsize=(20,8))
# Out:
# <AxesSubplot:>

# %%
sns.countplot(x='FirstHalf_Points_HomeTeam',hue='SecondHalf_Points_HomeTeam',data=df_4)
plt.show()

# %%
# pair plot of data
plt.figure(figsize=(10,5))
sns.pairplot(df_4)

# %%
df_4.duplicated().sum()
# Out:
# 0
