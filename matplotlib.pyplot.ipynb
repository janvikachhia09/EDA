# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df=pd.DataFrame(np.random.randn(1000),columns=['data'])

# %%
df
# Out:
#          data
# 0   -0.537179
# 1    1.035066
# 2    0.414926
# 3   -0.651464
# 4   -1.377968
# ..        ...
# 995  0.258559
# 996  1.385320
# 997  0.900271
# 998 -0.731795
# 999 -0.441478
#
# [1000 rows x 1 columns]

# %%
df=pd.DataFrame(np.random.randn(1000,3),columns=['data','num','name'])

# %%
df
# Out:
#          data       num      name
# 0    0.752761  0.212263  0.080201
# 1    0.611817  0.312730  0.340748
# 2   -0.391766  0.151072 -0.426983
# 3   -0.335826  2.302604 -1.014569
# 4   -0.425952  1.372995 -3.017850
# ..        ...       ...       ...
# 995 -1.793324 -1.214539  2.358548
# 996 -0.826999  0.199769  1.333110
# 997 -0.072711 -1.693109  1.521442
# 998  1.500628 -0.105767 -0.578223
# 999 -0.447078  1.248476 -1.300993
#
# [1000 rows x 3 columns]

# %%
df.shape
# Out:
# (1000, 3)

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df.plot(figsize=(20,40))
# Out:
# <AxesSubplot:>

# %%
df['data'].plot()
# Out:
# <AxesSubplot:>

# %%
df.iloc[2:5].plot(kind='line',figsize=(4,5))
# Out:
# <AxesSubplot:>

# %%
df['data'].iloc[2:5].plot(kind='line',figsize=(4,5))
# Out:
# <AxesSubplot:>

# %%
pip install cufflinks
# Out:
# ...
#
# ...
#   Created wheel for cufflinks: filename=cufflinks-0.17.3-py3-none-any.whl size=68736 sha256=63a0202a91223559912fef8a41e676d6a44e7d8a56eaa0b991146711735f5285
#   Stored in directory: c:\users\lenovo\appdata\local\pip\cache\wheels\29\b4\f8\2fd2206eeeba6ccad8167e4e8894b8c4ec27bf1342037fd136
# Successfully built cufflinks
# ...

# %%
df.plot(kind='box')
# Out:
# <AxesSubplot:>
