# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly as py 
import plotly.tools as tls 
import cufflinks as cf 
# %matplotlib inline

# %%
df_3=pd.read_csv("C:\\Users\\lenovo\\Downloads\\archive (3)\\PlayerData.csv")

# %%
df_3.shape
# Out:
# (220, 30)

# %%
df_3.describe()
# Out:
#        Unnamed: 0  Match Played      Points  Career Best Points  \
# count  220.000000    220.000000  220.000000          220.000000
# mean   109.500000      9.563636   30.195455            5.077273
# std     63.652704      7.126422   44.399936            5.138131
# min      0.000000      0.000000    0.000000            0.000000
# 25%     54.750000      2.000000    1.750000            1.000000
# 50%    109.500000      9.000000   11.500000            4.000000
# 75%    164.250000     17.000000   46.000000            7.000000
# max    219.000000     20.000000  258.000000           29.000000
#
#        Not Out Percentage       Raids  Successful Raids  Unsuccessful Raids  \
# count          220.000000  220.000000        220.000000          220.000000
# mean            48.598273   43.740909         15.186364           10.381818
# std             38.827724   81.437772         34.776085           18.944756
# min              0.000000    0.000000          0.000000            0.000000
# ...

# %%
df_3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 220 entries, 0 to 219
# Data columns (total 30 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Unnamed: 0                    220 non-null    int64
#  1   Name                          220 non-null    object
#  2   Position                      220 non-null    object
#  3   Born                          220 non-null    object
#  4   Team                          220 non-null    object
#  5   Height                        220 non-null    object
#  6   Nationality                   220 non-null    object
#  7   Weight                        220 non-null    object
#  8   Match Played                  220 non-null    float64
#  9   Points                        220 non-null    float64
#  10  Career Best Points            220 non-null    float64
#  11  Not Out Percentage            220 non-null    float64
# ...

# %%
df_3.isnull().sum()
# Out:
# Unnamed: 0                      0
# Name                            0
# Position                        0
# Born                            0
# Team                            0
# Height                          0
# Nationality                     0
# Weight                          0
# Match Played                    0
# Points                          0
# Career Best Points              0
# Not Out Percentage              0
# Raids                           0
# Successful Raids                0
# Unsuccessful Raids              0
# Empty Raid                      0
# Successful Raid Percentage      0
# Raid Touch Points               0
# Raid Bonus Points               0
# Total Raid Points               0
# Super Raids                     0
# Super 10s                       0
# Tackles                         0
# Successful Tackles              0
# Unsuccessful Tackles            0
# Successful Tackles Per Match    0
# Tackle Bonus Points             0
# ...

# %%
df_3.groupby(['Position','Team'])['Team'].count()
# Out:
# Position     Team
# All Rounder  Bengal Warriors          6
#              Bengaluru Bulls          2
#              Dabang Delhi K.C.        3
#              Gujarat Fortunegiants    4
#              Haryana Steelers         1
#                                      ..
# Raider       Puneri Paltan            9
#              Tamil Thalaivas          7
#              Telugu Titans            9
#              U Mumba                  8
#              U.P. Yoddha              9
# Name: Team, Length: 80, dtype: int64

# %%
df_3.groupby(['Raid Touch Points','Team'])['Team'].count()
# Out:
# Raid Touch Points  Team
# 0.0                Bengal Warriors          15
#                    Bengaluru Bulls          11
#                    Dabang Delhi K.C.        12
#                    Gujarat Fortunegiants     7
#                    Haryana Steelers         10
#                                             ..
# 134.0              Haryana Steelers          1
# 175.0              Bengal Warriors           1
# 190.0              Bengaluru Bulls           1
# 199.0              Dabang Delhi K.C.         1
# 215.0              Patna Pirates             1
# Name: Team, Length: 101, dtype: int64

# %%
df_3.columns
# Out:
# Index(['Unnamed: 0', 'Name', 'Position', 'Born', 'Team', 'Height',
#        'Nationality', 'Weight', 'Match Played', 'Points', 'Career Best Points',
#        'Not Out Percentage', 'Raids', 'Successful Raids', 'Unsuccessful Raids',
#        'Empty Raid', 'Successful Raid Percentage', 'Raid Touch Points',
#        'Raid Bonus Points', 'Total Raid Points', 'Super Raids', 'Super 10s',
#        'Tackles', 'Successful Tackles', 'Unsuccessful Tackles',
#        'Successful Tackles Per Match', 'Tackle Bonus Points',
#        'Tackle Success Rate', 'Super Tackles', 'High 5s'],
#       dtype='object')

# %%
df_3.Team.unique()
# Out:
# array(['Bengal Warriors', 'Bengaluru Bulls', 'Dabang Delhi K.C.',
#        'Gujarat Fortunegiants', 'Haryana Steelers',
#        'Jaipur Pink Panthers', 'Patna Pirates', 'Puneri Paltan',
#        'Tamil Thalaivas', 'Telugu Titans', 'U Mumba', 'U.P. Yoddha'],
#       dtype=object)

# %%
sns.countplot('Match Played',data=df_3)
plt.show()
# Out:
# C:\Users\lenovo\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %%
# scatter plot of Team and Points
x=df_3['Team']
y=df_3['Points']
plt.scatter(x,y)
plt.xlabel('Team ',fontsize=10)
plt.ylabel('Points',fontsize=10)
# Out:
# Text(0, 0.5, 'Points')

# %%
df_3['Points'].min()
# Out:
# 0.0

# %%
df_3['Points'].max()
# Out:
# 258.0

# %%
plt.figure(figsize=(10,8))
sns.countplot('Nationality',data=df_3)
plt.show()
# Out:
# C:\Users\lenovo\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %%
df_3['Super Tackles'].plot(kind='bar',figsize=(10,8))
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(15,8))
sns.countplot(x='Nationality',hue='Position',data=df_3)
plt.show()

# %%
df_3['Career Best Points'].plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='Career Best Points'>

# %%
sns.boxplot('Super 10s',data=df_3)
plt.show()
# Out:
# C:\Users\lenovo\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %%
sns.barplot('Super Tackles',data=df_3)
plt.show()
# Out:
# C:\Users\lenovo\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %%
plt.figure(figsize=(15,8))
sns.countplot('Successful Tackles',data=df_3)
plt.show()
# Out:
# C:\Users\lenovo\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %%
df_3.duplicated().sum()
# Out:
# 0
