# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly as py 
import plotly.tools as tls 
import cufflinks as cf 
# %matplotlib inline

# %%
df_2=pd.read_csv("C:\\Users\\lenovo\\Downloads\\archive (3)\\Leaguetable.csv")

# %%
df_2.shape
# Out:
# (12, 9)

# %%
df_2.describe()
# Out:
#        Unnamed: 0       Rank          P          W          L          T  \
# count   12.000000  12.000000  12.000000  12.000000  12.000000  12.000000
# mean     5.500000   6.500000  19.333333   8.666667   8.666667   2.000000
# std      3.605551   3.605551   0.778499   3.601347   3.420083   0.852803
# min      0.000000   1.000000  18.000000   3.000000   3.000000   1.000000
# 25%      2.750000   3.750000  19.000000   6.000000   6.000000   1.000000
# 50%      5.500000   6.500000  19.500000   9.000000   9.000000   2.000000
# 75%      8.250000   9.250000  20.000000  10.500000  11.250000   3.000000
# max     11.000000  12.000000  20.000000  15.000000  14.000000   3.000000
#
#        Score Diff.        Pts
# count    12.000000  12.000000
# mean      0.000000  54.083333
# std      59.647449  15.715993
# min    -117.000000  31.000000
# 25%     -24.000000  41.500000
# 50%       5.500000  55.000000
# 75%      27.250000  60.500000
# max      95.000000  82.000000

# %%
df_2.columns
# Out:
# Index(['Unnamed: 0', 'Rank', 'Team', 'P', 'W', 'L', 'T', 'Score Diff.', 'Pts'], dtype='object')

# %%
df_2.isnull().sum()
# Out:
# Unnamed: 0     0
# Rank           0
# Team           0
# P              0
# W              0
# L              0
# T              0
# Score Diff.    0
# Pts            0
# dtype: int64

# %%
df_2.groupby(['Team','Rank'])['Rank'].count()
# Out:
# Team                   Rank
# Bengal Warriors        2       1
# Bengaluru Bulls        5       1
# Dabang Delhi K.C.      1       1
# Gujarat Fortunegiants  8       1
# Haryana Steelers       3       1
# Jaipur Pink Panthers   7       1
# Patna Pirates          10      1
# Puneri Paltan          9       1
# Tamil Thalaivas        12      1
# Telugu Titans          11      1
# U Mumba                4       1
# U.P. Yoddha            6       1
# Name: Rank, dtype: int64

# %%
df_2.groupby(['Pts','Team'])['Team'].count()
# Out:
# Pts  Team
# 31   Tamil Thalaivas          1
# 39   Telugu Titans            1
# 40   Patna Pirates            1
# 42   Puneri Paltan            1
# 45   Gujarat Fortunegiants    1
# 52   Jaipur Pink Panthers     1
# 58   Bengaluru Bulls          1
#      U.P. Yoddha              1
# 59   U Mumba                  1
# 65   Haryana Steelers         1
# 78   Bengal Warriors          1
# 82   Dabang Delhi K.C.        1
# Name: Team, dtype: int64

# %%
df_2.groupby(['Team','W'])['W'].count()
# Out:
# Team                   W
# Bengal Warriors        13    1
# Bengaluru Bulls        10    1
# Dabang Delhi K.C.      15    1
# Gujarat Fortunegiants  6     1
# Haryana Steelers       12    1
# Jaipur Pink Panthers   8     1
# Patna Pirates          6     1
# Puneri Paltan          6     1
# Tamil Thalaivas        3     1
# Telugu Titans          5     1
# U Mumba                10    1
# U.P. Yoddha            10    1
# Name: W, dtype: int64

# %%
df_2.groupby(['Team','L'])['L'].count()
# Out:
# Team                   L
# Bengal Warriors        4     1
# Bengaluru Bulls        8     1
# Dabang Delhi K.C.      3     1
# Gujarat Fortunegiants  12    1
# Haryana Steelers       6     1
# Jaipur Pink Panthers   10    1
# Patna Pirates          12    1
# Puneri Paltan          11    1
# Tamil Thalaivas        14    1
# Telugu Titans          10    1
# U Mumba                8     1
# U.P. Yoddha            6     1
# Name: L, dtype: int64

# %%
df_2.groupby(['Team','T'])['T'].count()
# Out:
# Team                   T
# Bengal Warriors        3    1
# Bengaluru Bulls        1    1
# Dabang Delhi K.C.      2    1
# Gujarat Fortunegiants  2    1
# Haryana Steelers       1    1
# Jaipur Pink Panthers   2    1
# Patna Pirates          1    1
# Puneri Paltan          3    1
# Tamil Thalaivas        3    1
# Telugu Titans          3    1
# U Mumba                1    1
# U.P. Yoddha            2    1
# Name: T, dtype: int64

# %%
df_2.groupby(['Team','Rank'])['Rank'].count()
sns.countplot('Team',hue='Rank',data=df_2,palette=['black','blue'],alpha=1)
plt.show()
# Out:
# C:\Users\lenovo\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %%
df_2.columns
# Out:
# Index(['Unnamed: 0', 'Rank', 'Team', 'P', 'W', 'L', 'T', 'Score Diff.', 'Pts'], dtype='object')

# %%
df_2.P.unique()
# Out:
# array([20, 19, 18], dtype=int64)

# %%
df_2.W.unique()
# Out:
# array([15, 13, 12, 10,  8,  6,  5,  3], dtype=int64)

# %%
df_2.L.unique()
# Out:
# array([ 3,  4,  6,  8, 10, 12, 11, 14], dtype=int64)

# %%
sns.countplot('Score Diff.',data=df_2)
plt.show()
# Out:
# C:\Users\lenovo\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %%
sns.countplot('Pts',data=df_2)
plt.show()
# Out:
# C:\Users\lenovo\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %%
sns.countplot('T',data=df_2)
plt.show()
# Out:
# C:\Users\lenovo\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %%
sns.countplot('W',data=df_2)
plt.show()
# Out:
# C:\Users\lenovo\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %%
sns.countplot('P',data=df_2)
plt.show()
# Out:
# C:\Users\lenovo\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %%
sns.countplot('L',data=df_2)
plt.show()
# Out:
# C:\Users\lenovo\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %%
sns.countplot('Rank',data=df_2)
plt.show()
# Out:
# C:\Users\lenovo\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %%
sns.set_style('dark')
sns.countplot(x='Team',data=df_2,palette='RdBu_r')
# Out:
# <AxesSubplot:xlabel='Team', ylabel='count'>

# %%
sns.countplot(x='P',hue='L',data=df_2)
plt.show()

# %%
sns.countplot(x='P',hue='W',data=df_2)
plt.show()

# %%
sns.countplot(x='P',hue='T',data=df_2)
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.countplot(data=df_2,x='L',hue='P')
# Out:
# <AxesSubplot:xlabel='L', ylabel='count'>

# %%
x=df_2['Rank']
y=df_2['Pts']
plt.scatter(x,y)
plt.xlabel('Rank',fontsize=10)
plt.ylabel('Pts',fontsize=10)
# Out:
# Text(0, 0.5, 'Pts')

# %%
plt.hist(df_2['Pts'])
# Out:
# (array([1., 2., 2., 0., 1., 3., 1., 0., 0., 2.]),
#  array([31. , 36.1, 41.2, 46.3, 51.4, 56.5, 61.6, 66.7, 71.8, 76.9, 82. ]),
#  <BarContainer object of 10 artists>)

# %%
# pair plot of data
plt.figure(figsize=(10,5))
sns.pairplot(df_2)

# %%
duplicate=df_2[df_2.duplicated()]
duplicate
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Rank, Team, P, W, L, T, Score Diff., Pts]
# Index: []

# %%
df_2.drop_duplicates(inplace=True)
df_2.duplicated().sum()
# Out:
# 0
