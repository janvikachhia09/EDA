# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly as py 
import plotly.tools as tls 
import cufflinks as cf 
# %matplotlib inline

# %%
np.random.randn(1000)
# Out:
# array([ 1.48631030e+00,  6.78393456e-02,  1.94771705e+00,  1.70800299e+00,
#         8.64634367e-01, -1.53089013e-01, -3.69967749e-01, -8.05556591e-01,
#        -1.20836921e+00, -5.02267077e-01, -6.81005703e-01, -1.91917663e-01,
#        -6.17772528e-01, -4.55171024e-01,  2.20329496e-02,  1.66868558e+00,
#        -6.73004433e-01, -1.58598890e+00,  8.85436685e-02, -5.26982874e-01,
#         6.46128014e-01, -1.18529900e-01,  9.97773753e-01,  9.32516393e-01,
#         6.08132447e-01,  4.74156374e-01, -3.55833666e-01,  1.10102027e-01,
#         1.63728280e+00,  4.55976763e-01,  1.20683333e+00,  1.05639661e+00,
#         7.35965341e-01, -2.56440238e-01,  6.15340534e-01,  2.21013841e+00,
#        -1.51132709e+00, -1.04767440e+00,  1.34934052e+00, -1.28616476e+00,
#        -1.74859930e-01, -1.00339575e-01, -8.77131365e-01,  8.30695602e-01,
#         9.15914550e-01, -7.19310871e-02,  1.66611841e+00, -6.99558509e-01,
# ...

# %%
df=pd.DataFrame(np.random.randn(1000),columns=['data'])

# %%
df.head()
# Out:
#        data
# 0 -0.391062
# 1  0.813284
# 2  0.135098
# 3  0.246638
# 4  1.551915

# %%
df.plot(figsize=(4,5))
# Out:
# <AxesSubplot:>

# %%
df=sns.load_dataset("iris")

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df['species'].unique
# Out:
# <bound method Series.unique of 0         setosa
# 1         setosa
# 2         setosa
# 3         setosa
# 4         setosa
#          ...
# 145    virginica
# 146    virginica
# 147    virginica
# 148    virginica
# 149    virginica
# Name: species, Length: 150, dtype: object>

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
sns.barplot('sepal_length','petal_length',hue='species',data=df)
# Out:
# C:\Users\lenovo\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
df.iloc[5:8].plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df.shape
# Out:
# (150, 5)

# %%
df.iloc[6:8].plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
df.iloc[5:8].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df['sepal_length'].plot(kind='hist',orientation='horizontal')
# Out:
# <AxesSubplot:xlabel='Frequency'>

# %%
df['sepal_length'].plot(kind='hist',orientation='vertical')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.hist(color='black',alpha=0.5)
# Out:
# array([[<AxesSubplot:title={'center':'sepal_length'}>,
#         <AxesSubplot:title={'center':'sepal_width'}>],
#        [<AxesSubplot:title={'center':'petal_length'}>,
#         <AxesSubplot:title={'center':'petal_width'}>]], dtype=object)

# %%
df.plot(kind="box",color={'boxes':'b' ,'whiskers':'r'})
# Out:
# <AxesSubplot:>

# %%
df.plot(kind='area',alpha=0.5,stacked=False)
# Out:
# <AxesSubplot:>

# %%
 df.plot(kind='area',alpha=0.5,stacked=True)
# Out:
# <AxesSubplot:>

# %%
df.plot.scatter(x='sepal_length', y='petal_length',c='sepal_length',s=100)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
df.plot.hexbin(x='sepal_length', y='petal_length',gridsize=10)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
df1=df.drop(columns='species').iloc[0]
df1.plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='0'>
